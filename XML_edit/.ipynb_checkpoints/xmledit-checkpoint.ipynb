# %%
#import required modules to handle xml language
import xml.etree.ElementTree as ET
#parse xml file
tree=ET.parse('N072p33602.xml')
root=tree.getroot()

# %%
for word in root.iter("w"):
    print (word.attrib)
# Out:
# {'lemma': 'wij', 'ana': 'c404', 'part': 'N'}
# {'lemma': 'johannes', 'ana': 'c020', 'part': 'N'}
# {'lemma': 'de kolvenaar', 'ana': 'c471 c021', 'part': 'N'}
# {'lemma': 'jacob', 'ana': 'c020', 'part': 'N'}
# {'lemma': 'van de werf', 'ana': 'c700 c471 c021', 'part': 'N'}
# {'lemma': 'johannes', 'ana': 'c020', 'part': 'N'}
# {'lemma': 'huigeman', 'ana': 'c020', 'rend': 'space(0)', 'part': 'N'}
# {'lemma': 'wilhelm', 'ana': 'c020', 'part': 'N'}
# {'lemma': 'de mijmer', 'ana': 'c471 c020', 'part': 'N'}
# {'lemma': 'en', 'ana': 'c800', 'part': 'N'}
# {'lemma': 'johannes', 'ana': 'c020', 'part': 'N'}
# {'lemma': 'van de vlierbeek', 'ana': 'c700 c474 c021', 'part': 'N'}
# {'lemma': 'schepen', 'ana': 'c011', 'part': 'N'}
# {'lemma': 'van', 'ana': 'c700', 'part': 'N'}
# {'lemma': 'de', 'ana': 'c474', 'part': 'N'}
# {'lemma': 'iepers', 'ana': 'c104', 'part': 'N'}
# {'lemma': 'ambacht', 'ana': 'c001', 'part': 'N'}
# {'lemma': 'doen', 'ana': 'c204', 'part': 'N'}
# ...
